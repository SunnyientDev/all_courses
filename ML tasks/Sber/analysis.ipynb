# %%
import numpy as np
import pandas as pd 


import matplotlib.pyplot as pltdata = datpd.read_csv('data.csv'), sep=';'
data.dcshape
# Out:
# (2111, 2)

# %%
data['VALUE'].hist()

# %%
fig = plt.figure(figsize=(25, 10))
ax = fig.add_subplot(111)

ax.scatter(data['REPORTDATE'], data['VALUE'])
plt.xlabel('Report date')
plt.ylabel('Value')

plt.show()

# %%
print(data['REPORTDATE'][0][3:5])
p
# Out:
# 12
# 3    02.01.2014
# 4    03.01.2014
# Name: REPORTDATE, dtype: object

# %%
fig = plt.figure(figsize=(25, 10))
ax = fig.add_subplot(111)

for i in range(2111):
    ax.bar(data['REPORTDATE'][i][3:5], data['VALUE'][i])
plt.xlabel('Report date')
plt.ylabel('Value')

plt.show()
